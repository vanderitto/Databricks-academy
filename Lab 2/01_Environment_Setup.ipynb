# %%
dbutils.widgets.text("catalog_name", "dbr_dev")
catalog_name = dbutils.widgets.get("catalog_name")

storage_account = "dlspl21databricks"
container = "janvander0912"
credential_name = "databricks_uc_connector" 

abfss_path = f"abfss://{container}@{storage_account}.dfs.core.windows.net/"

spark.sql(f"""
CREATE EXTERNAL LOCATION IF NOT EXISTS ext_janvander0912
URL '{abfss_path}'
WITH (STORAGE CREDENTIAL `{credential_name}`);
""")

# Medallion Architecture
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.janvander0912_bronze MANAGED LOCATION '{abfss_path}bronze'")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.janvander0912_silver MANAGED LOCATION '{abfss_path}silver'")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.janvander0912_gold MANAGED LOCATION '{abfss_path}gold'")
